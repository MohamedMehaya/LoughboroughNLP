# %% [markdown]
# This code was adapted from:
#
#
# *   https://www.geeksforgeeks.org/spelling-checker-in-python/
# *   NLP Labs

# %%
pip install pyspellchecker
# Out:
# Requirement already satisfied: pyspellchecker in /usr/local/lib/python3.7/dist-packages (0.6.3)

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy import array
from string import punctuation
from os import listdir
from collections import Counter
from nltk.corpus import stopwords
from pandas import DataFrame
from matplotlib import pyplot
import random
import nltk
from sklearn.decomposition import TruncatedSVD
from scipy.sparse import rand
from sklearn.metrics.pairwise import cosine_similarity
from numpy import argsort
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from collections import Counter
from nltk.stem.porter import PorterStemmer
from spellchecker import SpellChecker
nltk.download('punkt')
nltk.download('stopwords')

drive.mount("/content/drive")

data_path = "/content/drive/My Drive/Colab Notebooks/21COP509/LabDatasets/"
# !ls "/content/drive/My Drive/Colab Notebooks/21COP509/LabDatasets/"
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#  ArtsRatings_5000_test.txt	    JewelleryReviewsLSA.csv
#  ArtsRatings_5000_train.txt	    JewelleryReviewsQueryRelevantID.csv
#  ArtsReviews_5000_test.txt	    metamorphosis_clean.txt
#  ArtsReviews_5000_train.txt	   'My CW1.ipynb'
# 'F135864 - Task 1.ipynb'	   'My CW 2.ipynb'
# 'F135864 - Task 2.ipynb'	   'MY CW 3.ipynb'
# 'F135864 - Task 3.ipynb'	    Reduced_ArtsRatings_5000.txt
# 'F135864 - Task 4.ipynb'	    Reduced_ArtsReviews_5000.txt
# 'F135864 - Task 5.ipynb'	    review_polarity
#  glove.6B.100d.txt		    Untitled0.ipynb
#  JewelleryReviewsDeepLearning.csv

# %%
#Task 1

# load data
file = open(data_path + "JewelleryReviewsLSA.csv",'rt')
text = file.read()
file.close()
# split into words
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
# convert to lower case
tokens = [w.lower() for w in tokens]
# stemming of words
porter = PorterStemmer()
tokens = [porter.stem(word) for word in tokens]

# remove punctuation from each word
import string
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in tokens]
# remove remaining tokens that are not alphabetic
words = [word for word in stripped if word.isalpha()]
# filter out stop words
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]

#remove columns' titles
words = words[3:]

print(words[:100])
print(len(words))

#Correct spelling of words
spell = SpellChecker()
x = spell.unknown(words)   

for i in range (len(words)):
    # Replace each word by its correct spelling
    words[i] = spell.correction(words[i])

#check that the length of the array did not change
print(len(words))  
print(words)
# Out:
# ['expect', 'like', 'regular', 'size', 'ring', 'thi', 'one', 'look', 'like', 'ring', 'toy', 'someth', 'funi', 'mm', 'ring', 'thi', 'ring', 'may', 'cttw', 'round', 'diamond', 'solitair', 'ring', 'white', 'gold', 'order', 'ring', 'state', 'toe', 'ring', 'descript', 'ring', 'came', 'veri', 'quickli', 'wa', 'toe', 'ring', 'nt', 'know', 'anyon', 'size', 'toe', 'know', 'anyon', 'pleas', 'direct', 'thi', 'seller', 'wed', 'band', 'toe', 'ring', 'thumb', 'ring', 'pick', 'one', 'thi', 'ring', 'beauti', 'ring', 'first', 'shipment', 'thi', 'ring', 'scratch', 'diamond', 'wa', 'miss', 'diamond', 'shoulder', 'ring', 'return', 'ring', 'replac', 'ring', 'second', 'ring', 'wa', 'even', 'wors', 'clearli', 'visibl', 'white', 'scratch', 'right', 'middl', 'black', 'diamond', 'doe', 'look', 'great', 'thi', 'time', 'diamond', 'miss', 'shoulder', 'ring', 'return', 'refund']
# 3963
# 3963
# ['expect', 'like', 'regular', 'size', 'ring', 'thi', 'one', 'look', 'like', 'ring', 'toy', 'someth', 'fun', 'my', 'ring', 'thi', 'ring', 'may', 'cut', 'round', 'diamond', 'solitaire', 'ring', 'white', 'gold', 'order', 'ring', 'state', 'toe', 'ring', 'describe', 'ring', 'came', 'very', 'quickly', 'wa', 'toe', 'ring', 'it', 'know', 'anyon', 'size', 'toe', 'know', 'anyon', 'pleas', 'direct', 'thi', 'seller', 'wed', 'band', 'toe', 'ring', 'thumb', 'ring', 'pick', 'one', 'thi', 'ring', 'beauty', 'ring', 'first', 'shipment', 'thi', 'ring', 'scratch', 'diamond', 'wa', 'miss', 'diamond', 'shoulder', 'ring', 'return', 'ring', 'replace', 'ring', 'second', 'ring', 'wa', 'even', 'wors', 'clearly', 'visible', 'white', 'scratch', 'right', 'middl', 'black', 'diamond', 'doe', 'look', 'great', 'thi', 'time', 'diamond', 'miss', 'shoulder', 'ring', 'return', 'refund', 'thank', 'alot', 'amazon', 'thi', 'ring', 'beauty', 'ring', 'first', 'shipment', 'thi', 'ring', 'scratch', 'diamond', 'wa', 'miss', 'diamond', 'shoulder', 'ring', 'return', 'ring', 'replace', 'ring', 'second', 'ring', 'wa', 'even', 'wors', 'clearly', 'visible', 'white', 'scratch', 'right', 'middl', 'black', 'diamond', 'doe', 'look', 'great', 'thi', 'time', 'diamond', 'miss', 'shoulder', 'ring', 'return', 'refund', 'thank', 'alot', 'amazon', 'thi', 'huge', 'wast', 'money', 'month', 'part', 'hold', 'symbol', 'necklace', 'broke', 'serious', 'wast', 'money', 'thi', 'low', 'quality', 'quality', 'look', 'antics', 'very', 'flimsy', 'would', 'recommend', 'thi', 'quality', 'thi', 'item', 'wa', 'expectations', 'top', 'wa', 'scratch', 'hing', 'line', 'prevail', 'hole', 'stain', 'wa', 'consist', 'saw', 'thi', 'item', 'store', 'would', 'purchase', 'hard', 'ca', 'it', 'wear', 'mater', 'hard', 'easy', 'wear', 'it', 'like', 'save', 'money', 'got', 'e', 'want', 'know', 'thi', 'ring', 'like', 'ring', 'one', 'becaus', 'thi', 'ring', 'beyond', 'gorgeous', 'love', 'nice', 'ring', 'inexpert', 'ring', 'one', 'stone', 'wa', 'miss', 'wa', 'worth', 'return', 'would', 'pay', 'postal', 'ring', 'cost', 'wore', 'thi', 'toe', 'ring', 'one', 'day', 'poof', 'stone', 'wa', 'gone', 'sit', 'pile', 'broken', 'steal', 'silver', 'ring', 'ring', 'way', 'small', 'look', 'like', 'toy', 'put', 'would', 'recommend', 'want', 'nice', 'carat', 'only', 'week', 'befor', 'one', 'jewel', 'fell', 'wing', 'metal', 'already', 'tarnish', 'spend', 'money', 'higher', 'quality', 'want', 'favorit', 'pierce', 'mine', 'wear', 'bioplast', 'cuz', 'break', 'certain', 'serv', 'purpose', 'seem', 'imag', 'wa', 'lot', 'prettier', 'sparkler', 'turn', 'wear', 'shirt', 'since', 'doe', 'compliment', 'anyth', 'wear', 'thi', 'ring', 'beauty', 'ring', 'first', 'shipment', 'thi', 'ring', 'scratch', 'diamond', 'wa', 'miss', 'diamond', 'shoulder', 'ring', 'return', 'ring', 'replace', 'ring', 'second', 'ring', 'wa', 'even', 'wors', 'clearly', 'visible', 'white', 'scratch', 'right', 'middl', 'black', 'diamond', 'doe', 'look', 'great', 'thi', 'time', 'diamond', 'miss', 'shoulder', 'ring', 'return', 'refund', 'thank', 'alot', 'amazon', 'thi', 'ring', 'beauty', 'ring', 'first', 'shipment', 'thi', 'ring', 'scratch', 'diamond', 'wa', 'miss', 'diamond', 'shoulder', 'ring', 'return', 'ring', 'replace', 'ring', 'second', 'ring', 'wa', 'even', 'wors', 'clearly', 'visible', 'white', 'scratch', 'right', 'middl', 'black', 'diamond', 'doe', 'look', 'great', 'thi', 'time', 'diamond', 'miss', 'shoulder', 'ring', 'return', 'refund', 'thank', 'alot', 'amazon', 'very', 'nice', 'small', 'size', 'ring', 'stack', 'ring', 'differ', 'got', 'thi', 'ring', 'birthday', 'love', 'imagin', 'woman', 'adore', 'thi', 'ring', 'wa', 'first', 'skeptic', 'thi', 'ring', 'price', 'wa', 'very', 'low', 'it', 'wear', 'lot', 'gold', 'purchase', 'ring', 'nice', 'gold', 'necklace', 'wear', 'want', 'ring', 'work', 'ring', 'doe', 'it', 'look', 'like', 'thi', 'ring', 'awesome', 'wear', 'ring', 'index', 'finger', 'fit', 'great', 'comfort', 'only', 'ring', 'beauty', 'jewel', 'wa', 'very', 'accommad', 'ring', ...

# %%
counter = {}

for word in words:
  counter[word] = counter.get(word, 0) + 1

counter
# Out:
# {'above': 1,
#  'absolut': 10,
#  'accommad': 2,
#  'accordingly': 1,
#  'across': 1,
#  'actual': 6,
#  'add': 3,
#  'addict': 2,
#  'admir': 1,
#  'admit': 1,
#  'adore': 3,
#  'advertise': 2,
#  'afford': 2,
#  'alert': 1,
#  'ali': 1,
#  'allow': 1,
#  'almost': 6,
#  'along': 1,
#  'alot': 5,
#  'already': 3,
#  'also': 12,
#  'alter': 1,
#  'although': 3,
#  'alway': 8,
#  'amaz': 2,
#  'amazon': 8,
#  'amethyst': 3,
#  'amount': 1,
#  'anchor': 2,
#  'ani': 9,
#  'ann': 1,
#  'antics': 4,
#  'antique': 1,
#  'anymor': 1,
#  'anyon': 6,
#  'anyth': 3,
#  'anywher': 1,
#  'appeal': 1,
#  'appear': 3,
#  'appetit': 1,
#  'appreci': 3,
#  'are': 3,
#  'around': 4,
#  'arriv': 10,
#  'ask': 1,
#  'attent': 1,
#  'attract': 2,
#  'auction': 2,
#  'aunt': 1,
#  'authentic': 1,
#  'autism': 1,
#  'avenue': 2,
#  'avoid': 1,
#  'avon': 1,
#  'awar': 2,
#  'away': 2,
#  'awesome': 4,
#  'awhile': 1,
#  'babi': 3,
#  'back': 5,
#  'bad': 1,
#  'bail': 1,
#  'band': 9,
#  'bank': 1,
#  'bare': 3,
#  'base': 1,
#  'basic': 1,
#  'be': 1,
#  'bead': 4,
#  'beautiful': 1,
#  'beauty': 37,
#  'becaus': 15,
#  'becom': 1,
#  'befor': 3,
#  'begin': 1,
#  'behind': 1,
#  'believ': 2,
#  'belli': 1,
#  'bend': 2,
#  'bent': 1,
#  'best': 1,
#  'better': 9,
#  'beyond': 2,
#  'big': 5,
#  'bigger': 3,
#  'bill': 1,
#  'bioplast': 1,
#  'birth': 1,
#  'birthday': 7,
#  'birthstone': 1,
#  'bit': 4,
#  'black': 9,
#  'bling': 1,
#  'blue': 15,
#  'bolder': 1,
#  'bolduniqu': 1,
#  'bought': 20,
#  'bow': 1,
#  'box': 2,
#  'boy': 1,
#  'boyfriend': 1,
#  'bracelet': 18,
#  'break': 2,
#  'breath': 1,
#  'bright': 1,
#  'brilliant': 1,
#  'brilliantly': 2,
#  'broke': 3,
#  'broken': 2,
#  'brush': 1,
#  'budget': 1,
#  'bug': 1,
#  'build': 1,
#  'bulkier': 2,
#  'busi': 1,
#  'buy': 20,
#  'buyer': 1,
#  'ca': 4,
#  'came': 9,
#  'cant': 1,
#  'car': 1,
#  'carat': 1,
#  'care': 4,
#  'carnelian': 1,
#  'case': 1,
#  'casual': 2,
#  'catch': 7,
#  'celtic': 3,
#  'certain': 1,
#  'chain': 1,
#  'chance': 1,
#  'charm': 5,
#  'cheap': 4,
#  'cheaper': 1,
#  'check': 1,
#  'children': 1,
#  'choice': 1,
#  'choose': 1,
#  'christmas': 4,
#  'claddaugh': 1,
#  'clasp': 4,
#  'class': 2,
#  'classic': 1,
#  'classify': 1,
#  'claw': 1,
#  'clean': 2,
#  'cleaner': 1,
#  'clear': 2,
#  'clearly': 6,
#  'click': 1,
#  'clodagh': 1,
#  'close': 3,
#  'cloth': 1,
#  'cloud': 1,
#  'clunky': 1,
#  'cluster': 6,
#  'coach': 1,
#  'coast': 1,
#  'collect': 2,
#  'college': 1,
#  'color': 21,
#  'come': 1,
#  'comfort': 6,
#  'comment': 2,
#  'company': 3,
#  'compare': 3,
#  'complaint': 2,
#  'complet': 7,
#  'completly': 3,
#  'compliment': 10,
#  'conduit': 2,
#  'consist': 1,
#  'contact': 1,
#  'contain': 1,
#  'continue': 1,
#  'cool': 2,
#  'correctly': 1,
#  'cost': 3,
#  'costum': 1,
#  'could': 10,
#  'couldnt': 1,
#  'counter': 1,
#  'cours': 2,
#  'crack': 2,
#  'craftsmanship': 2,
#  'crisp': 1,
#  'cross': 6,
#  'cubic': 4,
#  'cure': 2,
#  'custom': 5,
#  'cut': 5,
#  'cute': 4,
#  'cuz': 1,
#  'daily': 1,
#  'dainty': 2,
#  'damage': 2,
#  'dark': 2,
#  'date': 2,
#  'daughter': 3,
#  'day': 5,
#  'dead': 1,
#  'deal': 3,
#  'debt': 1,
#  'decent': 3,
#  'decide': 3,
#  'deep': 1,
#  'defi': 1,
#  'define': 3,
#  'definite': 11,
#  'deliver': 2,
#  'describe': 8,
#  'deserve': 1,
#  'design': 4,
#  'detail': 4,
#  'diamond': 30,
#  'diamondgreat': 1,
#  'differ': 6,
#  'direct': 2,
#  'disappoint': 9,
#  'discomfort': 1,
#  'disconcert': 1,
#  'discover': 1,
#  'disgust': 1,
#  'doe': 16,
#  'doesnt': 1,
#  'dollar': 1,
#  'dont': 2,
#  'dorothy': 1,
#  'doubt': 1,
#  'dress': 2,
#  'dresser': 1,
#  'due': 1,
#  'dull': 1,
#  'durable': 1,
#  'e': 1,
#  'ear': 8,
#  'earlier': 3,
#  'easily': 2,
#  'easy': 2,
#  'egg': 1,
#  'egypt': 1,
#  'either': 4,
#  'elsewhere': 1,
#  'enamel': 3,
#  'end': 6,
#  'engage': 9,
#  'enjoy': 2,
#  'enough': 4,
#  'eri': 1,
#  'espect': 2,
#  'eve': 2,
#  'even': 14,
#  'ever': 12,
#  'everyday': 4,
#  'everyone': 4,
#  'everyth': 2,
#  'exactly': 4,
#  'excel': 3,
#  'except': 1,
#  'exit': 6,
#  'expect': 10,
#  'expectations': 1,
#  'expense': 5,
#  'experi': 1,
#  'explain': 1,
#  'extend': 1,
#  'extreme': 4,
#  'extremely': 1,
#  'eye': 2,
#  'face': 1,
#  'fact': 2,
#  'fair': 1,
#  'fall': 2,
#  'family': 1,
#  'fan': 3,
#  'far': 2,
#  'fashion': 1,
#  'fast': 4,
#  'faster': 1,
#  'favorit': 2,
#  'feb': 1,
#  'feel': 2,
#  'fell': 4,
#  'feminine': 1,
#  'fianc': 1,
#  'fill': 1,
#  'find': 4,
#  'finger': 8,
#  'finish': 2,
#  'firmly': 1,
#  'first': 14,
#  'fit': 16,
#  'five': 1,
#  'flaw': 3,
#  'flexible': 5,
#  'flimsy': 2,
#  'floor': 1,
#  'flower': 3,
#  'flute': 2,
#  'form': 1,
#  'formal': 1,
#  'forward': 2,
#  'found': 1,
#  'fragile': 2,
#  'frame': 1,
#  'friend': 4,
#  'fring': 1,
#  'frustrate': 1,
#  'fun': 1,
#  'funky': 1,
#  'fuse': 2,
#  'futur': 1,
#  'garnet': 3,
#  'gem': 2,
#  'gemstone': 2,
#  'get': 5,
#  'gift': 18,
#  'girl': 1,
#  'girlfriend': 5,
#  'give': 1,
#  'given': 2,
#  'glad': 2,
#  'glass': 1,
#  'go': 13,
#  'gold': 7,
#  'gone': 1,
#  'good': 9,
#  'gorgeous': 6,
#  'got': 18,
#  'gotten': 1,
#  'grace': 1,
#  'gradual': 1,
#  'great': 27,
#  'greatly': 1,
#  'green': 2,
#  'guard': 1,
#  'guess': 2,
#  'guy': 1,
#  'ha': 11,
#  'halloween': 1,
#  'hams': 1,
#  'hand': 7,
#  'handl': 1,
#  'happen': 1,
#  'happi': 7,
#  'hard': 3,
#  'hardly': 1,
#  'harm': 2,
#  'hat': 1,
#  'head': 2,
#  'heart': 6,
#  'hearthat': 1,
#  'heist': 1,
#  'help': 7,
#  'hi': 1,
#  'high': 6,
#  'higher': 1,
#  'highlight': 1,
#  'hing': 1,
#  'hit': 1,
#  'hold': 4,
#  'holder': 1,
#  'hole': 1,
#  'holi': 1,
#  'holiday': 1,
#  'hollow': 1,
#  'home': 1,
#  'honor': 1,
#  'hook': 1,
#  'hope': 3,
#  'horn': 1,
#  'horrible': 1,
#  'hour': 1,
#  'hous': 1,
#  'howe': 4,
#  'hubby': 1,
#  'huge': 3,
#  'husband': 4,
#  'i': 3,
#  'im': 3,
#  'imag': 2,
#  'imagin': 3,
#  'impede': 1,
#  'impose': 3,
#  'impress': 5,
#  'include': 2,
#  'increase': 1,
#  'index': 2,
#  'individual': 2,
#  'inexpert': 1,
#  'inner': 1,
#  'instead': 1,
#  'insubstantial': 1,
#  'interact': 1,
#  'internet': 1,
#  'isnt': 1,
#  'it': 39,
#  'italian': 2,
#  'itch': 1,
#  'item': 33,
#  'jersey': 1,
#  'jewel': 4,
#  'jewelry': 4,
#  'jewlery': 2,
#  'joint': 4,
#  'judo': 1,
#  'june': 1,
#  'junk': 1,
#  'justice': 1,
#  'keep': 1,
#  'kept': 2,
#  'key': 1,
#  'kind': 1,
#  'know': 7,
#  'lack': 1,
#  'land': 1,
#  'lapel': 2,
#  'large': 2,
#  'largest': 1,
#  'last': 4,
#  'lavender': 1,
#  'lay': 2,
#  'lead': 1,
#  'learn': 1,
#  'least': 1,
#  'leav': 3,
#  'left': 1,
#  'leg': 3,
#  'less': 2,
#  'lessen': 1,
#  'lie': 2,
#  'life': 3,
#  'light': 6,
#  'like': 63,
#  'likest': 1,
#  'limit': 1,
#  'line': 4,
#  'lip': 2,
#  'littl': 14,
#  'lobe': 1,
#  'local': 1,
#  'lol': 1,
#  'long': 2,
#  'look': 98,
#  'loos': 1,
#  'lose': 3,
#  'lost': 6,
#  'lostthe': 1,
#  'lot': 7,
#  'love': 49,
#  'lover': 2,
#  'low': 5,
#  'loyal': 3,
#  'luminous': 1,
#  'machin': 1,
#  'made': 3,
#  'mail': 2,
#  'make': 8,
#  'man': 3,
#  'mani': 5,
#  'manner': 3,
#  'mark': 1,
#  'market': 1,
#  'marriage': 1,
#  'mason': 1,
#  'mater': 1,
#  'matter': 1,
#  'maul': 1,
#  'may': 5,
#  'mean': 1,
#  'measure': 1,
#  'medic': 1,
#  'medical': 1,
#  'member': 1,
#  'memory': 2,
#  'mention': 1,
#  'mess': 1,
#  'message': 1,
#  'met': 1,
#  'metal': 5,
#  'microscope': 1,
#  'middl': 8,
#  'million': 1,
#  'mine': 4,
#  'mislead': 2,
#  'misrepres': 1,
#  'miss': 9,
#  'mom': 1,
#  'money': 9,
#  'month': 3,
#  'mother': 1,
#  'much': 12,
#  'mussel': 1,
#  'must': 4,
#  'my': 2,
#  'narrow': 1,
#  'necklace': 8,
#  'need': 5,
#  'neil': 1,
#  'nervous': 1,
#  'nevada': 1,
#  'never': 1,
#  'new': 5,
#  'next': 2,
#  'nice': 27,
#  'night': 2,
#  'none': 1,
#  'noth': 10,
#  'nothin': 1,
#  'notice': 6,
#  'numer': 3,
#  'occasionswear': 1,
#  'of': 1,
#  'often': 1,
#  'old': 3,
#  'olive': 1,
#  'one': 39,
#  'online': 4,
#  'only': 14,
#  'onto': 1,
#  'open': 2,
#  'opinion': 1,
#  'orang': 1,
#  'orcas': 2,
#  'order': 22,
#  'otherwise': 2,
#  'outside': 1,
#  'outward': 1,
#  'overall': 3,
#  'overs': 1,
#  'pace': 1,
#  'package': 2,
#  'pain': 1,
#  'pale': 1,
#  'part': 4,
#  'particular': 3,
#  'pass': 2,
#  'past': 2,
#  'pay': 2,
#  'peace': 1,
#  'pearl': 1,
#  'pendant': 1,
#  'peopl': 3,
#  'perfect': 15,
#  'perfectly': 6,
#  'period': 1,
#  'person': 6,
#  'pewter': 2,
#  'photograph': 1,
#  'pick': 2,
#  'pictur': 44,
#  'piece': 4,
#  'pierce': 1,
#  'pile': 1,
#  'pin': 1,
#  'pinch': 1,
#  'pini': 1,
#  'pink': 11,
#  'pinker': 1,
#  'place': 1,
#  'plain': 1,
#  'plan': 1,
#  'platinum': 2,
#  'pleas': 9,
#  'pleasur': 1,
#  'plenty': 1,
#  'point': 1,
#  'polish': 3,
#  'poof': 1,
#  'poor': 7,
#  'poorer': 1,
#  'portion': 1,
#  'posit': 2,
#  'postal': 1,
#  'present': 3,
#  'press': 1,
#  'prettier': 2,
#  'pretty': 18,
#  'prevail': 1,
#  'previous': 1,
#  'price': 18,
#  'pride': 1,
#  'princess': 2,
#  'pristine': 1,
#  'pro': 1,
#  'probabl': 1,
#  'product': 13,
#  'profession': 1,
#  'prom': 1,
#  'promis': 1,
#  'promptly': 2,
#  'provide': 1,
#  'purchase': 17,
#  'purity': 1,
#  'purple': 2,
#  'purpose': 1,
#  'push': 1,
#  'put': 1,
#  'quality': 39,
#  'quick': 3,
#  'quickly': 5,
#  'quit': 8,
#  'radiant': 1,
#  'ran': 1,
#  'rate': 1,
#  'reach': 2,
#  'read': 1,
#  'real': 7,
#  'reality': 1,
#  'really': 12,
#  'reason': 2,
#  'rec': 1,
#  'receiv': 27,
#  'recent': 3,
#  'recomend': 1,
#  'recommend': 15,
#  'record': 1,
#  'rectangular': 1,
#  'refund': 5,
#  'regret': 1,
#  'regular': 2,
#  'relic': 3,
#  'remove': 2,
#  'replace': 9,
#  'resin': 2,
#  'respond': 1,
#  'return': 16,
#  'revers': 1,
#  'review': 4,
#  'rhe': 1,
#  'rich': 1,
#  'rides': 1,
#  'ridicule': 1,
#  'right': 10,
#  'rigth': 1,
#  'ring': 379,
#  'ringreciev': 3,
#  'ripoff': 1,
#  'roll': 1,
#  'rosary': 4,
#  'round': 1,
#  'said': 1,
#  'sand': 1,
#  'sapphire': 1,
#  'satisfy': 4,
#  'save': 2,
#  'saw': 2,
#  'say': 5,
#  'school': 1,
#  'scratch': 10,
#  'scrutiny': 1,
#  'search': 1,
#  'second': 8,
#  'section': 2,
#  'secure': 1,
#  'see': 7,
#  'seem': 5,
#  'seen': 4,
#  'selfutterli': 1,
#  'seller': 12,
#  'selleramazon': 1,
#  'send': 3,
#  'sent': 2,
#  'serious': 1,
#  'serv': 1,
#  'service': 3,
#  'set': 3,
#  'sever': 3,
#  'shade': 1,
#  'shape': 3,
#  'share': 1,
#  'sharp': 1,
#  'shell': 1,
#  'shinai': 1,
#  'shine': 7,
#  'ship': 8,
#  'shipment': 4,
#  'shipmentdeliveri': 1,
#  'shirt': 1,
#  'shop': 2,
#  'short': 1,
#  'shoulder': 8,
#  'show': 7,
#  'side': 8,
#  'sign': 1,
#  'significa': 1,
#  'silver': 19,
#  'similar': 3,
#  'simple': 2,
#  'since': 8,
#  'sit': 2,
#  'site': 5,
#  'size': 20,
#  'skeptic': 2,
#  'slightly': 1,
#  'slow': 1,
#  'slowly': 1,
#  'small': 18,
#  'smaller': 4,
#  'smell': 1,
#  'smith': 2,
#  'smooth': 4,
#  'smush': 1,
#  'snake': 1,
#  'snap': 1,
#  'snug': 1,
#  'soft': 1,
#  'softer': 1,
#  'sold': 1,
#  'solid': 2,
#  'solidbeauti': 1,
#  'solidly': 1,
#  'solitaire': 2,
#  'someon': 2,
#  'someth': 7,
#  'son': 1,
#  'sooner': 1,
#  'sore': 1,
#  'soul': 1,
#  'spare': 1,
#  'spark': 8,
#  'sparkle': 1,
#  'sparkler': 1,
#  'speak': 2,
#  'specific': 1,
#  'specify': 1,
#  'speed': 1,
#  'spend': 3,
#  'spent': 1,
#  'spin': 2,
#  'sport': 1,
#  'square': 1,
#  'squish': 1,
#  'stack': 3,
#  'stain': 1,
#  'stand': 2,
#  'state': 3,
#  'stay': 1,
#  'steal': 8,
#  'still': 5,
#  'stim': 1,
#  'stone': 23,
#  'stop': 1,
#  'store': 3,
#  'straight': 1,
#  'straighten': 2,
#  'strand': 1,
#  'stuck': 1,
#  'stuff': 1,
#  'stun': 3,
#  'sturdy': 2,
#  'style': 2,
#  'sublimis': 1,
#  'suggest': 2,
#  'suit': 3,
#  'suitable': 1,
#  'sun': 1,
#  'super': 1,
#  'supply': 1,
#  'support': 1,
#  'sure': 2,
#  'surprise': 5,
#  'surprize': 1,
#  'swollen': 1,
#  'symbol': 3,
#  'take': 3,
#  'tan': 1,
#  'tarnish': 2,
#  'tast': 2,
#  'team': 1,
#  'teenage': 1,
#  'tell': 2,
#  'temporary': 1,
#  'tend': 1,
#  'thank': 10,
#  'therefor': 1,
#  'thi': 202,
#  'thick': 3,
#  'thicker': 1,
#  'thin': 3,
#  'thing': 9,
#  'think': 5,
#  'third': 1,
#  'though': 5,
#  'thought': 5,
#  'thousand': 1,
#  'three': 1,
#  'thrill': 1,
#  'thumb': 4,
#  'tiger': 1,
#  'tight': 1,
#  'till': 1,
#  'time': 22,
#  'timely': 1,
#  'tiny': 1,
#  'toe': 8,
#  'toget': 3,
#  'told': 1,
#  'tongue': 2,
#  'took': 2,
#  'top': 2,
#  'topaz': 10,
#  'torch': 1,
#  'total': 5,
#  'toward': 1,
#  'tower': 1,
#  'towork': 1,
#  'toy': 2,
#  'transact': 1,
#  'transluc': 1,
#  'tree': 1,
#  'tri': 2,
#  'trinity': 1,
#  'trip': 1,
#  'true': 3,
#  'truly': 3,
#  'turn': 5,
#  'turtle': 1,
#  'two': 5,
#  'type': 2,
#  'undescib': 1,
#  'unfasten': 1,
#  'unfortune': 2,
#  'unfussi': 1,
#  'unique': 1,
#  'update': 1,
#  'upon': 3,
#  'us': 2,
#  'use': 3,
#  'usual': 1,
#  'vacant': 3,
#  'vaccum': 1,
#  'valentin': 1,
#  'variety': 1,
#  'various': 1,
#  'ver': 1,
#  'very': 74,
#  'visible': 4,
#  'visual': 1,
#  'wa': 106,
#  'waa': 1,
#  'want': 18,
#  'war': 1,
#  'warn': 1,
#  'wast': 3,
#  'way': 7,
#  'wear': 61,
#  'wed': 11,
#  'week': 2,
#  'weekend': 1,
#  'weight': 1,
#  'welcome': 1,
#  'well': 4,
#  'went': 1,
#  'whene': 1,
#  'whi': 2,
#  'white': 9,
#  'whole': 1,
#  'wide': 1,
#  'wider': 1,
#  'wife': 3,
#  'willow': 1,
#  'wing': 1,
#  'winter': 1,
#  'wish': 4,
#  'within': 2,
#  'without': 5,
#  'wo': 1,
#  'woman': 4,
#  'wonder': 5,
#  'wonderland': 1,
#  'wood': 1,
#  'word': 1,
#  'wore': 2,
#  'work': 8,
#  'workmanship': 1,
#  'worn': 1,
#  'worry': 3,
#  'wors': 4,
#  'worth': 7,
#  'would': 33,
#  'written': 1,
#  'wrong': 1,
#  'year': 3,
#  'yellow': 3,
#  'yesterday': 1,
#  'yet': 2,
#  'yo': 1,
#  'young': 1,
#  'zirconia': 3}

# %%
x= words
x
# Out:
# ['expect',
#  'like',
#  'regular',
#  'size',
#  'ring',
#  'thi',
#  'one',
#  'look',
#  'like',
#  'ring',
#  'toy',
#  'someth',
#  'fun',
#  'my',
#  'ring',
#  'thi',
#  'ring',
#  'may',
#  'cut',
#  'round',
#  'diamond',
#  'solitaire',
#  'ring',
#  'white',
#  'gold',
#  'order',
#  'ring',
#  'state',
#  'toe',
#  'ring',
#  'describe',
#  'ring',
#  'came',
#  'very',
#  'quickly',
#  'wa',
#  'toe',
#  'ring',
#  'it',
#  'know',
#  'anyon',
#  'size',
#  'toe',
#  'know',
#  'anyon',
#  'pleas',
#  'direct',
#  'thi',
#  'seller',
#  'wed',
#  'band',
#  'toe',
#  'ring',
#  'thumb',
#  'ring',
#  'pick',
#  'one',
#  'thi',
#  'ring',
#  'beauty',
#  'ring',
#  'first',
#  'shipment',
#  'thi',
#  'ring',
#  'scratch',
#  'diamond',
#  'wa',
#  'miss',
#  'diamond',
#  'shoulder',
#  'ring',
#  'return',
#  'ring',
#  'replace',
#  'ring',
#  'second',
#  'ring',
#  'wa',
#  'even',
#  'wors',
#  'clearly',
#  'visible',
#  'white',
#  'scratch',
#  'right',
#  'middl',
#  'black',
#  'diamond',
#  'doe',
#  'look',
#  'great',
#  'thi',
#  'time',
#  'diamond',
#  'miss',
#  'shoulder',
#  'ring',
#  'return',
#  'refund',
#  'thank',
#  'alot',
#  'amazon',
#  'thi',
#  'ring',
#  'beauty',
#  'ring',
#  'first',
#  'shipment',
#  'thi',
#  'ring',
#  'scratch',
#  'diamond',
#  'wa',
#  'miss',
#  'diamond',
#  'shoulder',
#  'ring',
#  'return',
#  'ring',
#  'replace',
#  'ring',
#  'second',
#  'ring',
#  'wa',
#  'even',
#  'wors',
#  'clearly',
#  'visible',
#  'white',
#  'scratch',
#  'right',
#  'middl',
#  'black',
#  'diamond',
#  'doe',
#  'look',
#  'great',
#  'thi',
#  'time',
#  'diamond',
#  'miss',
#  'shoulder',
#  'ring',
#  'return',
#  'refund',
#  'thank',
#  'alot',
#  'amazon',
#  'thi',
#  'huge',
#  'wast',
#  'money',
#  'month',
#  'part',
#  'hold',
#  'symbol',
#  'necklace',
#  'broke',
#  'serious',
#  'wast',
#  'money',
#  'thi',
#  'low',
#  'quality',
#  'quality',
#  'look',
#  'antics',
#  'very',
#  'flimsy',
#  'would',
#  'recommend',
#  'thi',
#  'quality',
#  'thi',
#  'item',
#  'wa',
#  'expectations',
#  'top',
#  'wa',
#  'scratch',
#  'hing',
#  'line',
#  'prevail',
#  'hole',
#  'stain',
#  'wa',
#  'consist',
#  'saw',
#  'thi',
#  'item',
#  'store',
#  'would',
#  'purchase',
#  'hard',
#  'ca',
#  'it',
#  'wear',
#  'mater',
#  'hard',
#  'easy',
#  'wear',
#  'it',
#  'like',
#  'save',
#  'money',
#  'got',
#  'e',
#  'want',
#  'know',
#  'thi',
#  'ring',
#  'like',
#  'ring',
#  'one',
#  'becaus',
#  'thi',
#  'ring',
#  'beyond',
#  'gorgeous',
#  'love',
#  'nice',
#  'ring',
#  'inexpert',
#  'ring',
#  'one',
#  'stone',
#  'wa',
#  'miss',
#  'wa',
#  'worth',
#  'return',
#  'would',
#  'pay',
#  'postal',
#  'ring',
#  'cost',
#  'wore',
#  'thi',
#  'toe',
#  'ring',
#  'one',
#  'day',
#  'poof',
#  'stone',
#  'wa',
#  'gone',
#  'sit',
#  'pile',
#  'broken',
#  'steal',
#  'silver',
#  'ring',
#  'ring',
#  'way',
#  'small',
#  'look',
#  'like',
#  'toy',
#  'put',
#  'would',
#  'recommend',
#  'want',
#  'nice',
#  'carat',
#  'only',
#  'week',
#  'befor',
#  'one',
#  'jewel',
#  'fell',
#  'wing',
#  'metal',
#  'already',
#  'tarnish',
#  'spend',
#  'money',
#  'higher',
#  'quality',
#  'want',
#  'favorit',
#  'pierce',
#  'mine',
#  'wear',
#  'bioplast',
#  'cuz',
#  'break',
#  'certain',
#  'serv',
#  'purpose',
#  'seem',
#  'imag',
#  'wa',
#  'lot',
#  'prettier',
#  'sparkler',
#  'turn',
#  'wear',
#  'shirt',
#  'since',
#  'doe',
#  'compliment',
#  'anyth',
#  'wear',
#  'thi',
#  'ring',
#  'beauty',
#  'ring',
#  'first',
#  'shipment',
#  'thi',
#  'ring',
#  'scratch',
#  'diamond',
#  'wa',
#  'miss',
#  'diamond',
#  'shoulder',
#  'ring',
#  'return',
#  'ring',
#  'replace',
#  'ring',
#  'second',
#  'ring',
#  'wa',
#  'even',
#  'wors',
#  'clearly',
#  'visible',
#  'white',
#  'scratch',
#  'right',
#  'middl',
#  'black',
#  'diamond',
#  'doe',
#  'look',
#  'great',
#  'thi',
#  'time',
#  'diamond',
#  'miss',
#  'shoulder',
#  'ring',
#  'return',
#  'refund',
#  'thank',
#  'alot',
#  'amazon',
#  'thi',
#  'ring',
#  'beauty',
#  'ring',
#  'first',
#  'shipment',
#  'thi',
#  'ring',
#  'scratch',
#  'diamond',
#  'wa',
#  'miss',
#  'diamond',
#  'shoulder',
#  'ring',
#  'return',
#  'ring',
#  'replace',
#  'ring',
#  'second',
#  'ring',
#  'wa',
#  'even',
#  'wors',
#  'clearly',
#  'visible',
#  'white',
#  'scratch',
#  'right',
#  'middl',
#  'black',
#  'diamond',
#  'doe',
#  'look',
#  'great',
#  'thi',
#  'time',
#  'diamond',
#  'miss',
#  'shoulder',
#  'ring',
#  'return',
#  'refund',
#  'thank',
#  'alot',
#  'amazon',
#  'very',
#  'nice',
#  'small',
#  'size',
#  'ring',
#  'stack',
#  'ring',
#  'differ',
#  'got',
#  'thi',
#  'ring',
#  'birthday',
#  'love',
#  'imagin',
#  'woman',
#  'adore',
#  'thi',
#  'ring',
#  'wa',
#  'first',
#  'skeptic',
#  'thi',
#  'ring',
#  'price',
#  'wa',
#  'very',
#  'low',
#  'it',
#  'wear',
#  'lot',
#  'gold',
#  'purchase',
#  'ring',
#  'nice',
#  'gold',
#  'necklace',
#  'wear',
#  'want',
#  'ring',
#  'work',
#  'ring',
#  'doe',
#  'it',
#  'look',
#  'like',
#  'thi',
#  'ring',
#  'awesome',
#  'wear',
#  'ring',
#  'index',
#  'finger',
#  'fit',
#  'great',
#  'comfort',
#  'only',
#  'ring',
#  'beauty',
#  'jewel',
#  'wa',
#  'very',
#  'accommad',
#  'ring',
#  'reach',
#  'us',
#  'time',
#  'appreci',
#  'care',
#  'quick',
#  'receiv',
#  'ring',
#  'thank',
#  'love',
#  'ring',
#  'ring',
#  'would',
#  'want',
#  'wear',
#  'everyday',
#  'ring',
#  'claw',
#  'hold',
#  'stone',
#  'very',
#  'sharp',
#  'get',
#  'stuck',
#  'thing',
#  'scratch',
#  'bought',
#  'thi',
#  'ring',
#  'valentin',
#  'gift',
#  'could',
#  'it',
#  'give',
#  'since',
#  'hand',
#  'hold',
#  'heart',
#  'symbol',
#  'would',
#  'revers',
#  'whene',
#  'ring',
#  'spin',
#  'thi',
#  'ring',
#  'alter',
#  'face',
#  'direct',
#  'cute',
#  'ring',
#  'kept',
#  'thi',
#  'ring',
#  'wa',
#  'littl',
#  'small',
#  'ring',
#  'finger',
#  'would',
#  'better',
#  'pink',
#  'ring',
#  'pretty',
#  'enough',
#  'metal',
#  'ring',
#  'very',
#  'insubstantial',
#  'push',
#  'very',
#  'easily',
#  'husband',
#  'love',
#  'only',
#  'thing',
#  'cant',
#  'thi',
#  'ring',
#  'resin',
#  'due',
#  'way',
#  'ring',
#  'ring',
#  'pretty',
#  'very',
#  'flexible',
#  'turn',
#  'good',
#  'becaus',
#  'order',
#  'ring',
#  'finger',
#  'size',
#  'made',
#  'look',
#  'better',
#  'pink',
#  'definite',
#  'help',
#  'lessen',
#  'appetit',
#  'howe',
#  'ear',
#  'sore',
#  'wear',
#  'hour',
#  'next',
#  'day',
#  'tri',
#  'wear',
#  'increase',
#  'wear',
#  'time',
#  'good',
#  'pain',
#  'tower',
#  'may',
#  'notice',
#  'ani',
#  'discomfort',
#  'ear',
#  'lobe',
#  'swollen',
#  'stop',
#  'wear',
#  'day',
#  'got',
#  'belli',
#  'ring',
#  'tongue',
#  'ring',
#  'lip',
#  'ring',
#  'car',
#  'stuff',
#  'got',
#  'wa',
#  'cool',
#  'love',
#  'pink',
#  'peace',
#  'sign',
#  'tongue',
#  'ring',
#  'only',
#  'complaint',
#  'got',
#  'yellow',
#  'lip',
#  'ring',
#  'im',
#  'much',
#  'yellow',
#  'overall',
#  'very',
#  'happi',
#  'similar',
#  'ring',
#  'auction',
#  'site',
#  'flaw',
#  'lie',
#  'middl',
#  'part',
#  'ring',
#  'complet',
#  'ring',
#  'cut',
#  'flexible',
#  'joint',
#  'end',
#  'take',
#  'mine',
#  'silver',
#  'smith',
#  'remove',
#  'back',
#  'section',
#  'middl',
#  'ring',
#  'really',
#  'help',
#  'flexible',
#  'similar',
#  'ring',
#  'auction',
#  'site',
#  'flaw',
#  'lie',
#  'middl',
#  'part',
#  'ring',
#  'complet',
#  'ring',
#  'cut',
#  'flexible',
#  'joint',
#  'end',
#  'take',
#  'mine',
#  'silver',
#  'smith',
#  'remove',
#  'back',
#  'section',
#  'middl',
#  'ring',
#  'really',
#  'help',
#  'flexible',
#  'only',
#  'wish',
#  'thi',
#  'ring',
#  'wish',
#  'cut',
#  'portion',
#  'went',
#  'way',
#  'around',
#  'ring',
#  'great',
#  'very',
#  'comfort',
#  'ring',
#  'wa',
#  'ship',
#  'accordingly',
#  'love',
#  'ship',
#  'pace',
#  'ring',
#  'beauty',
#  'only',
#  'thing',
#  'it',
#  'care',
#  'line',
#  'look',
#  'like',
#  'ring',
#  'may',
#  'resin',
#  'include',
#  'specify',
#  'include',
#  'ring',
#  'ha',
#  'met',
#  'expect',
#  'espect',
#  'begin',
#  'ring',
#  'husband',
#  'wear',
#  'size',
#  'ring',
#  'wa',
#  'tight',
#  'new',
#  'thumb',
#  'ring',
#  'guess',
#  'it',
#  'order',
#  'thing',
#  'online',
#  'cute',
#  'told',
#  'ring',
#  'very',
#  'comfort',
#  'wear',
#  'wa',
#  'quit',
#  'surprise',
#  'pleas',
#  'see',
#  'mason',
#  'ring',
#  'it',
#  'even',
#  'order',
#  'thi',
#  'ring',
#  'read',
#  'review',
#  'notice',
#  'pictur',
#  'pictur',
#  'two',
#  'differ',
#  'ring',
#  'wa',
#  'go',
#  'order',
#  'ring',
#  'seem',
#  'ring',
#  'receiv',
#  'ring',
#  'ha',
#  'smaller',
#  'cross',
#  'pictur',
#  'thi',
#  'ring',
#  'show',
#  'blue',
#  'sapphire',
#  'wa',
#  'disappoint',
#  'see',
#  'ring',
#  'receiv',
#  'ha',
#  'dark',
#  'stone',
#  'appear',
#  'black',
#  'ring',
#  'definite',
#  'thi',
#  'favorit',
#  'ring',
#  'also',
#  'one',
#  'first',
#  'ring',
#  'ever',
#  'bought',
#  'new',
#  'buy',
#  'pewter',
#  'ring',
#  'someth',
#  'may',
#  'help',
#  'pewter',
#  'ring',
#  'tend',
#  'bit',
#  'bulkier',
#  'type',
#  'ring',
#  'metal',
#  'softer',
#  'past',
#  'like',
#  'thi',
#  'ring',
#  'design',
#  'dead',
#  'bug',
#  'snake',
#  'catch',
#  'lot',
#  'attent',
#  'product',
#  'came',
#  'very',
#  'fast',
#  'wa',
#  'like',
#  'amazon',
#  'explain',
#  'itch',
#  'ring',
#  'very',
#  'clearly',
#  'written',
#  'war',
#  'thick',
#  'likest',
#  'guess',
#  'like',
#  'small',
#  'ring',
#  'thi',
#  'isnt',
#  'very',
#  'nice',
#  'small',
#  'size',
#  'ring',
#  'stack',
#  'ring',
#  'differ',
#  'thi',
#  'attract',
#  'high',
#  'quality',
#  'item',
#  'young',
#  'teenage',
#  'small',
#  'could',
#  'see',
#  'quality',
#  'work',
#  'thi',
#  'rosary',
#  'wa',
#  'pleas',
#  'open',
#  'contain',
#  'could',
#  'impede',
#  'smell',
#  'olive',
#  'wood',
#  'wa',
#  'only',
#  'one',
#  'thing',
#  'buyer',
#  'need',
#  'awar',
#  'buy',
#  'thi',
#  'item',
#  'wa',
#  'it',
#  'mention',
#  'describe',
#  'holi',
#  'land',
#  'sand',
#  'present',
#  'compare',
#  'rosary',
#  'opinion',
#  'thi',
#  'add',
#  'quality',
#  'rosary',
#  'sure',
#  'whi',
#  'seller',
#  'it',
#  'describe',
#  'thi',
#  'fact',
#  'look',
#  'item',
#  'thi',
#  'seller',
#  'love',
#  'thi',
#  'ring',
#  'only',
#  'complaint',
#  'metal',
#  'soft',
#  'bent',
#  'point',
#  'couldnt',
#  'wear',
#  'anymor',
#  'still',
#  'wear',
#  'necklace',
#  'love',
#  'orcas',
#  'squish',
#  'onto',
#  'finger',
#  'took',
#  'less',
#  'two',
#  'month',
#  'almost',
#  'impose',
#  'spark',
#  'pretty',
#  'dainty',
#  'wa',
#  'look',
#  'thi',
#  'solidbeauti',
#  'ring',
#  'expect',
#  'color',
#  'rhe',
#  'pictur',
#  'disappoint',
#  'bare',
#  'pink',
#  'first',
#  'saw',
#  'thought',
#  'wa',
#  'lavender',
#  'still',
#  'pretty',
#  'buy',
#  'design',
#  'thi',
#  'beauty',
#  'piece',
#  'look',
#  'long',
#  'time',
#  'replace',
#  'hams',
#  'hand',
#  'wa',
#  'given',
#  'egypt',
#  'thi',
#  'one',
#  'perfect',
#  'relic',
#  'sturdy',
#  'love',
#  'look',
#  'detail',
#  'pretty',
#  'leg',
#  'wear',
#  'bought',
#  'two',
#  'ring',
#  'fit',
#  'either',
#  'side',
#  'platinum',
#  'princess',
#  'wed',
#  'ring',
#  'help',
#  'anchor',
#  'add',
#  'ring',
#  'perfect',
#  'fit',
#  'lot',
#  'compliment',
#  'new',
#  'ring',
#  ...]

# %%
# importing the nltk suite
import nltk

# importing jaccard distance
# and ngrams from nltk.util
from nltk.metrics.distance import jaccard_distance
from nltk.util import ngrams

# %%
# Downloading and importing
# package 'words' from nltk corpus
nltk.download('words')
from nltk.corpus import words
  
  
correct_words = words.words()
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
# list of incorrect spellings
# that need to be corrected
incorrect_words=['happpy', 'azmaing', 'intelliengt']


# loop for finding correct spellings
# based on jaccard distance
# and printing the correct word
for word in x:
	temp = [(jaccard_distance(set(ngrams(word, 2)),
							set(ngrams(w, 2))),w)
			for w in correct_words if w[0]==word[0]]
	print(sorted(temp, key = lambda val:val[0])[0][1])
# Out:
# expect
# like
# regular
# size
# ring
# thig
# one
# look
# like
# ring
# toy
# something
# fun
# my
# ring
# thig
# ring
# may
# cut
# round
# diamond
# solitaire
# ring
# white
# gold
# order
# ring
# state
# toe
# ring
# describe
# ring
# came
# very
# quickly
# wa
# toe
# ring
# it
# know
# anyone
# size
# toe
# know
# anyone
# please
# direct
# thig
# seller
# wed
# band
# toe
# ring
# thumb
# ring
# pick
# one
# thig
# ring
# beauty
# ring
# first
# shipment
# thig
# ring
# scratch
# diamond
# wa
# miss
# diamond
# shoulder
# ring
# return
# ring
# replace
# ring
# second
# ring
# wa
# even
# worse
# clearly
# visible
# white
# scratch
# right
# middle
# black
# diamond
# doe
# look
# great
# thig
# time
# diamond
# miss
# shoulder
# ring
# return
# refund
# thank
# allot
# amazonite
# thig
# ring
# beauty
# ring
# first
# shipment
# thig
# ring
# scratch
# diamond
# wa
# miss
# diamond
# shoulder
# ring
# return
# ring
# replace
# ring
# second
# ring
# wa
# even
# worse
# clearly
# visible
# white
# scratch
# right
# middle
# black
# diamond
# doe
# look
# great
# thig
# time
# diamond
# miss
# shoulder
# ring
# return
# refund
# thank
# allot
# amazonite
# thig
# huge
# wast
# money
# month
# part
# hold
# symbol
# necklace
# broke
# serious
# wast
# money
# thig
# low
# quality
# quality
# look
# antic
# very
# flimsy
# would
# recommend
# thig
# quality
# thig
# item
# wa
# expectation
# top
# wa
# scratch
# hing
# line
# prevail
# hole
# stain
# wa
# consist
# saw
# thig
# item
# store
# would
# purchase
# hard
# ca
# it
# wear
# mater
# hard
# easy
# wear
# it
# like
# save
# money
# got
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-8-201e63d6b5a1> in <module>()
#      10 	temp = [(jaccard_distance(set(ngrams(word, 2)),
#      11 							set(ngrams(w, 2))),w)
# ---> 12 			for w in correct_words if w[0]==word[0]]
#      13         print(sorted(temp, key = lambda val:val[0])[0][1])
#
# <ipython-input-8-201e63d6b5a1> in <listcomp>(.0)
#      10 	temp = [(jaccard_distance(set(ngrams(word, 2)),
#      11 							set(ngrams(w, 2))),w)
# ---> 12 			for w in correct_words if w[0]==word[0]]
#      13         print(sorted(temp, key = lambda val:val[0])[0][1])
#
# /usr/local/lib/python3.7/dist-packages/nltk/metrics/distance.py in jaccard_distance(label1, label2)
#     113
#     114     """
# --> 115     return (len(label1.union(label2)) - len(label1.intersection(label2)))/len(label1.union(label2))
#     116
#     117
#
# ZeroDivisionError: division by zero
